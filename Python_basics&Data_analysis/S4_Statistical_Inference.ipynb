# %% [markdown]
# ### This notebook is written by Jiawen Liang for the AccFin PhD workshop: Python for Data Analysis in Nov 2022. Please do not circulate without permission.

# %% [markdown]
# # Statistical models
#
# ## topics
#
# - statistical hypothesis t tests
#
# - normality tests
#
# - portfolio optimization
#
# - linear regression

# %%
# Please install statsmodel at the first time.
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: scipy>=1.1 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from statsmodels) (1.6.2)
# Requirement already satisfied: patsy>=0.5 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: numpy>=1.15 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from statsmodels) (1.20.1)
# Requirement already satisfied: pandas>=0.21 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from statsmodels) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21->statsmodels) (2021.1)
# Requirement already satisfied: six in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from patsy>=0.5->statsmodels) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %% [markdown]
# ## t-test
# - to test whether the means of two independent samples are significantly different.
#
# - Hypothesis:
#
# H0: the means of the samples are equal.
#
# H1: the means of the samples are unequal.

# %%
# Exampls
# ttest_ind: calculate the T-test for the means of two independent samples of scores.
from scipy.stats import ttest_ind
d1 = [0.843, 2.49, 1.394, -0.394, -0.349, -1.135, -1.149]
d2 = [1.142, -0.850, -0.942, 0.395, -1.395, -1.502, -1.425]

stat, p = ttest_ind(d1, d2)
print("t-statistics%.3f"% stat, "p%.3f"% p)

if p > 0.05:
    print('Probably the same distribution')
    print("cannot reject H0")
else:
    print('Probably different distributions')
    print("reject H0")
# Out:
# t-statistics1.384 p0.192
# Probably the same distribution
# cannot reject H0

# %% [markdown]
# ## Normaility tests
# - to validate the assumption that data are normally distributed.
# - important for financial models, such as MV, CAPM.
# - e.g. check whether returns are normally distributed.

# %%
price_df = pd.read_csv("data/stock_prices.csv")
price_df.head()
# Out:
#          date      AAPL        GE     AMD       WMT       BAC         T  \
# 0  29/12/1989  0.117203  0.352438  3.9375  3.486070  1.752478  2.365775
# 1  02/01/1990  0.123853  0.364733  4.1250  3.660858  1.766686  2.398184
# 2  03/01/1990  0.124684  0.364050  4.0000  3.660858  1.780897  2.356516
# 3  04/01/1990  0.125100  0.362001  3.9375  3.641439  1.743005  2.403821
# 4  05/01/1990  0.125516  0.358586  3.8125  3.602595  1.705114  2.287973
#
#         XOM  RRC       BBY       PFE       JPM
# 0  1.766756  NaN  0.166287  0.110818  1.827968
# 1  1.766756  NaN  0.173216  0.113209  1.835617
# 2  1.749088  NaN  0.194001  0.113608  1.896803
# 3  1.731422  NaN  0.190537  0.115402  1.904452
# 4  1.722587  NaN  0.190537  0.114405  1.912100

# %%
price_df.set_index("date")
# Out:
#                   AAPL         GE      AMD        WMT        BAC          T  \
# date
# 29/12/1989    0.117203   0.352438   3.9375   3.486070   1.752478   2.365775
# 02/01/1990    0.123853   0.364733   4.1250   3.660858   1.766686   2.398184
# 03/01/1990    0.124684   0.364050   4.0000   3.660858   1.780897   2.356516
# 04/01/1990    0.125100   0.362001   3.9375   3.641439   1.743005   2.403821
# 05/01/1990    0.125516   0.358586   3.8125   3.602595   1.705114   2.287973
# ...                ...        ...      ...        ...        ...        ...
# 05/04/2018  172.800003  13.430000  10.0200  87.809998  30.320000  35.632843
# 06/04/2018  168.380005  13.060000   9.6100  86.690002  29.629999  35.130001
# 09/04/2018  170.050003  12.830000   9.5300  86.279999  29.870001  35.169998
# 10/04/2018  173.250000  13.050000   9.9800  86.449997  30.480000  35.810001
# 11/04/2018  172.440002  12.970000   9.8200  85.910004  29.900000  35.250000
#
#                   XOM    RRC        BBY        PFE         JPM
# date
# 29/12/1989   1.766756    NaN   0.166287   0.110818    1.827968
# 02/01/1990   1.766756    NaN   0.173216   0.113209    1.835617
# 03/01/1990   1.749088    NaN   0.194001   0.113608    1.896803
# 04/01/1990   1.731422    NaN   0.190537   0.115402    1.904452
# 05/01/1990   1.722587    NaN   0.190537   0.114405    1.912100
# ...               ...    ...        ...        ...         ...
# 05/04/2018  76.019997  14.52  72.120003  35.730000  111.879997
# 06/04/2018  74.870003  13.97  70.489998  35.169998  109.089996
# 09/04/2018  74.870003  13.93  69.820000  35.459999  110.400002
# 10/04/2018  77.070000  14.78  71.720001  35.950001  112.510002
# 11/04/2018  77.430000  14.99  70.910004  35.790001  110.620003
#
# [7126 rows x 11 columns]

# %%
log_return = np.log(price_df.AAPL) - np.log(price_df.AAPL.shift(1))

# %%
# normality test
# quantiles
sm.qqplot(log_return.dropna(), line='s')
plt.title('AAPL')
plt.xlabel('theoretical quantiles')
plt.ylabel('sample quantiles')
# Out:
# Text(0, 0.5, 'sample quantiles')

# %% [markdown]
# The sample quantile values do not lie on a straight line, indicating “non-normality.”!

# %% [markdown]
# ## Portfolio optimization
# - use library: pypfopt
# - a very useful and open-source library to do portfolio optimization
# - include expected returns, covariance matrix, mean-variance optimization, sharpe ratio, efficient frontier...

# %%
pip install PyPortfolioOpt
# Out:
# Collecting PyPortfolioOpt
#   Using cached pyportfolioopt-1.5.3-py3-none-any.whl (61 kB)
# Collecting cvxpy<2.0.0,>=1.1.10
#   Downloading cvxpy-1.2.1-cp38-cp38-macosx_10_9_x86_64.whl (880 kB)
#      |████████████████████████████████| 880 kB 240 kB/s eta 0:00:01
# Requirement already satisfied: scipy<2.0,>=1.3 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from PyPortfolioOpt) (1.6.2)
# Requirement already satisfied: pandas>=0.19 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from PyPortfolioOpt) (1.2.4)
# Collecting numpy<2.0.0,>=1.22.4
#   Downloading numpy-1.23.4-cp38-cp38-macosx_10_9_x86_64.whl (18.1 MB)
#      |████████████████████████████████| 18.1 MB 341 kB/s eta 0:00:01    |█████████▏                      | 5.2 MB 389 kB/s eta 0:00:34
# Collecting ecos>=2
#   Downloading ecos-2.0.10-cp38-cp38-macosx_10_9_x86_64.whl (88 kB)
#      |████████████████████████████████| 88 kB 561 kB/s eta 0:00:01
# Collecting osqp>=0.4.1
#   Downloading osqp-0.6.2.post5-cp38-cp38-macosx_10_9_x86_64.whl (249 kB)
#      |████████████████████████████████| 249 kB 640 kB/s eta 0:00:01
# Collecting scs>=1.1.6
#   Downloading scs-3.2.0-cp38-cp38-macosx_10_9_x86_64.whl (11.4 MB)
#      |████████████████████████████████| 11.4 MB 514 kB/s eta 0:00:01
# Collecting qdldl
#   Downloading qdldl-0.1.5.post2-cp38-cp38-macosx_10_9_x86_64.whl (97 kB)
#      |████████████████████████████████| 97 kB 387 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.19->PyPortfolioOpt) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.19->PyPortfolioOpt) (1.15.0)
# Collecting numpy<2.0.0,>=1.22.4
#   Downloading numpy-1.22.4-cp38-cp38-macosx_10_15_x86_64.whl (17.6 MB)
#      |████████████████████████████████| 17.6 MB 1.5 MB/s eta 0:00:01
# Installing collected packages: numpy, qdldl, scs, osqp, ecos, cvxpy, PyPortfolioOpt
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.1
#     Uninstalling numpy-1.20.1:
#       Successfully uninstalled numpy-1.20.1
# Successfully installed PyPortfolioOpt-1.5.3 cvxpy-1.2.1 ecos-2.0.10 numpy-1.22.4 osqp-0.6.2.post5 qdldl-0.1.5.post2 scs-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.84-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.4.4)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: pandas>=0.24.0 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.2.4)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: lxml>=4.5.1 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.0->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.26->yfinance) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2020.12.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/liangjiawen/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2.10)
# Installing collected packages: charset-normalizer, requests, multitasking, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# Successfully installed charset-normalizer-2.1.1 multitasking-0.0.11 requests-2.28.1 yfinance-0.1.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

from pypfopt import expected_returns
from pypfopt import risk_models
from pypfopt import EfficientFrontier

tickers = ["MSFT", "AMZN", "KO", "MA", "COST", 
           "LUV", "XOM", "PFE", "JPM", "UNH"] 

ohlc = yf.download(tickers, period="max")
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
ohlc.columns
# Out:
# MultiIndex([('Adj Close', 'AMZN'),
#             ('Adj Close', 'COST'),
#             ('Adj Close',  'JPM'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'LUV'),
#             ('Adj Close',   'MA'),
#             ('Adj Close', 'MSFT'),
#             ('Adj Close',  'PFE'),
#             ('Adj Close',  'UNH'),
#             ('Adj Close',  'XOM'),
#             (    'Close', 'AMZN'),
#             (    'Close', 'COST'),
#             (    'Close',  'JPM'),
#             (    'Close',   'KO'),
#             (    'Close',  'LUV'),
#             (    'Close',   'MA'),
#             (    'Close', 'MSFT'),
#             (    'Close',  'PFE'),
#             (    'Close',  'UNH'),
#             (    'Close',  'XOM'),
#             (     'High', 'AMZN'),
#             (     'High', 'COST'),
#             (     'High',  'JPM'),
#             (     'High',   'KO'),
#             (     'High',  'LUV'),
#             (     'High',   'MA'),
#             (     'High', 'MSFT'),
#             (     'High',  'PFE'),
#             (     'High',  'UNH'),
#             (     'High',  'XOM'),
#             (      'Low', 'AMZN'),
#             (      'Low', 'COST'),
#             (      'Low',  'JPM'),
#             (      'Low',   'KO'),
#             (      'Low',  'LUV'),
#             (      'Low',   'MA'),
#             (      'Low', 'MSFT'),
#             (      'Low',  'PFE'),
#             (      'Low',  'UNH'),
#             (      'Low',  'XOM'),
#             (     'Open', 'AMZN'),
#             (     'Open', 'COST'),
#             (     'Open',  'JPM'),
#             (     'Open',   'KO'),
#             (     'Open',  'LUV'),
#             (     'Open',   'MA'),
#             (     'Open', 'MSFT'),
#             (     'Open',  'PFE'),
#             (     'Open',  'UNH'),
#             (     'Open',  'XOM'),
#             (   'Volume', 'AMZN'),
#             (   'Volume', 'COST'),
#             (   'Volume',  'JPM'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'LUV'),
#             (   'Volume',   'MA'),
#             (   'Volume', 'MSFT'),
#             (   'Volume',  'PFE'),
#             (   'Volume',  'UNH'),
#             (   'Volume',  'XOM')],
#            )

# %%
price_df2 = ohlc["Adj Close"].dropna(how="all")
price_df2.head()
# Out:
#             AMZN  COST  JPM        KO  LUV  MA  MSFT  PFE  UNH       XOM
# Date
# 1962-01-02   NaN   NaN  NaN  0.050016  NaN NaN   NaN  NaN  NaN  0.099852
# 1962-01-03   NaN   NaN  NaN  0.048902  NaN NaN   NaN  NaN  NaN  0.101335
# 1962-01-04   NaN   NaN  NaN  0.049273  NaN NaN   NaN  NaN  NaN  0.101582
# 1962-01-05   NaN   NaN  NaN  0.048159  NaN NaN   NaN  NaN  NaN  0.099357
# 1962-01-08   NaN   NaN  NaN  0.047664  NaN NaN   NaN  NaN  NaN  0.099110

# %%
price_df2[price_df2.index >= "2008-01-01"].plot(figsize=(15,10));

# %%
mu = expected_returns.mean_historical_return(price_df2)
mu
# Out:
# AMZN    0.311679
# COST    0.122124
# JPM     0.117188
# KO      0.123639
# LUV     0.133761
# MA      0.302792
# MSFT    0.251796
# PFE     0.117208
# UNH     0.248279
# XOM     0.122438
# dtype: float64

# %%
S = risk_models.risk_matrix(price_df2)
S
# Out:
#           AMZN      COST       JPM        KO       LUV        MA      MSFT  \
# AMZN  0.330745  0.048032  0.066274  0.020215  0.048054  0.057057  0.072811
# COST  0.048032  0.101407  0.038562  0.021403  0.031193  0.032459  0.037511
# JPM   0.066274  0.038562  0.128130  0.027796  0.049198  0.069529  0.049308
# KO    0.020215  0.021403  0.027796  0.053580  0.022967  0.026282  0.027806
# LUV   0.048054  0.031193  0.049198  0.022967  0.138665  0.048773  0.037008
# MA    0.057057  0.032459  0.069529  0.026282  0.048773  0.118198  0.049757
# MSFT  0.072811  0.037511  0.049308  0.027806  0.037008  0.049757  0.114613
# PFE   0.031222  0.025421  0.032780  0.026054  0.025941  0.032246  0.030674
# UNH   0.034893  0.027545  0.038640  0.023021  0.032465  0.042754  0.034065
# XOM   0.026806  0.020346  0.033169  0.020630  0.023463  0.041753  0.029015
#
#            PFE       UNH       XOM
# AMZN  0.031222  0.034893  0.026806
# COST  0.025421  0.027545  0.020346
# JPM   0.032780  0.038640  0.033169
# KO    0.026054  0.023021  0.020630
# LUV   0.025941  0.032465  0.023463
# MA    0.032246  0.042754  0.041753
# MSFT  0.030674  0.034065  0.029015
# PFE   0.076161  0.028325  0.022980
# UNH   0.028325  0.161684  0.022460
# XOM   0.022980  0.022460  0.052675

# %%
ef = EfficientFrontier(None, S, weight_bounds=(None, None))
ef.min_volatility()
weights = ef.clean_weights()
weights
# Out:
# OrderedDict([('AMZN', 0.00917),
#              ('COST', 0.11424),
#              ('JPM', -0.00751),
#              ('KO', 0.3048),
#              ('LUV', 0.06498),
#              ('MA', -0.04839),
#              ('MSFT', 0.01993),
#              ('PFE', 0.13541),
#              ('UNH', 0.05526),
#              ('XOM', 0.35211)])

# %%
pd.Series(weights).plot.barh();

# %% [markdown]
# ## Linear regression

# %%
X = [[1],[2],[3],[4],[5]] # independent variables: 2 dimensional form 
Y = [2,4,6,8,10]
plt.scatter(X,Y) # scatter diagram
plt.show()

# %%
# Scikit-Learn
ln_reg = LinearRegression()
ln_reg.fit(X,Y) # use fit() to build the linear regression model
# Out:
# LinearRegression()

# %%
y = ln_reg.predict([[1.5]])
y
# Out:
# array([3.])

# %%
y = ln_reg.predict([[1.5], [2.4],[3.4]])
y
# Out:
# array([3. , 4.8, 6.8])

# %%
plt.scatter(X,Y)
plt.plot(X, ln_reg.predict(X))
plt.show()

# %%
# coefficient
str(ln_reg.coef_[0])
# Out:
# '2.0'

# %%
# intercept
str(ln_reg.intercept_)
# Out:
# '0.0'

# %%
# so, the predicted linear model is Y = 2X

# %% [markdown]
# Please import the dataset in "data/linear_regression" folder.
# in the trainning dataset: x can best estimate y.
#
# This dataset is downloaded from Kaggle: https://www.kaggle.com/datasets/andonians/random-linear-regression

# %%
train_df = pd.read_csv("data/linear_regression/train.csv")
train_df.head(5)
# Out:
#       x          y
# 0  24.0  21.549452
# 1  50.0  47.464463
# 2  15.0  17.218656
# 3  38.0  36.586398
# 4  87.0  87.288984

# %%
train_df.isnull().sum()
# Out:
# x    0
# y    1
# dtype: int64

# %%
train_df.dropna(inplace=True)

# %%
x1 = train_df.x.values.reshape(-1, 1) #-1: it is an unknown dimension and we want numpy to figure it out
y1 = train_df.y.values

# %%
x1
# Out:
# array([[ 24.],
#        [ 50.],
#        [ 15.],
#        [ 38.],
#        [ 87.],
#        [ 36.],
#        [ 12.],
#        [ 81.],
#        [ 25.],
#        [  5.],
#        [ 16.],
#        [ 16.],
#        [ 24.],
#        [ 39.],
#        [ 54.],
#        [ 60.],
#        [ 26.],
#        [ 73.],
#        [ 29.],
#        [ 31.],
#        [ 68.],
#        [ 87.],
#        [ 58.],
#        [ 54.],
#        [ 84.],
#        [ 58.],
#        [ 49.],
#        [ 20.],
#        [ 90.],
#        [ 48.],
#        [  4.],
#        [ 25.],
#        [ 42.],
#        [  0.],
#        [ 60.],
#        [ 93.],
#        [ 39.],
#        [  7.],
#        [ 21.],
#        [ 68.],
#        [ 84.],
#        [  0.],
#        [ 58.],
#        [ 19.],
#        [ 36.],
#        [ 19.],
#        [ 59.],
#        [ 51.],
#        [ 19.],
#        [ 33.],
#        [ 85.],
#        [ 44.],
#        [  5.],
#        [ 59.],
#        [ 14.],
#        [  9.],
#        [ 75.],
#        [ 69.],
#        [ 10.],
#        [ 17.],
#        [ 58.],
#        [ 74.],
#        [ 21.],
#        [ 51.],
#        [ 19.],
#        [ 50.],
#        [ 24.],
#        [  0.],
#        [ 12.],
#        [ 75.],
#        [ 21.],
#        [ 64.],
#        [  5.],
#        [ 58.],
#        [ 32.],
#        [ 41.],
#        [  7.],
#        [  4.],
#        [  5.],
#        [ 49.],
#        [ 90.],
#        [  3.],
#        [ 11.],
#        [ 32.],
#        [ 83.],
#        [ 25.],
#        [ 83.],
#        [ 26.],
#        [ 76.],
#        [ 95.],
#        [ 53.],
#        [ 77.],
#        [ 42.],
#        [ 25.],
#        [ 54.],
#        [ 55.],
#        [  0.],
#        [ 73.],
#        [ 35.],
#        [ 86.],
#        [ 90.],
#        [ 13.],
#        [ 46.],
#        [ 46.],
#        [ 32.],
#        [  8.],
#        [ 71.],
#        [ 28.],
#        [ 24.],
#        [ 56.],
#        [ 49.],
#        [ 79.],
#        [ 90.],
#        [ 89.],
#        [ 41.],
#        [ 27.],
#        [ 58.],
#        [ 26.],
#        [ 31.],
#        [ 70.],
#        [ 71.],
#        [ 39.],
#        [  7.],
#        [ 48.],
#        [ 56.],
#        [ 45.],
#        [ 41.],
#        [  3.],
#        [ 37.],
#        [ 24.],
#        [ 68.],
#        [ 47.],
#        [ 27.],
#        [ 68.],
#        [ 74.],
#        [ 95.],
#        [ 79.],
#        [ 21.],
#        [ 95.],
#        [ 54.],
#        [ 56.],
#        [ 80.],
#        [ 26.],
#        [ 25.],
#        [  8.],
#        [ 95.],
#        [ 94.],
#        [ 54.],
#        [  7.],
#        [ 99.],
#        [ 36.],
#        [ 48.],
#        [ 65.],
#        [ 42.],
#        [ 93.],
#        [ 86.],
#        [ 26.],
#        [ 51.],
#        [100.],
#        [ 94.],
#        [  6.],
#        [ 24.],
#        [ 75.],
#        [  7.],
#        [ 53.],
#        [ 73.],
#        [ 16.],
#        [ 80.],
#        [ 77.],
#        [ 89.],
#        [ 80.],
#        [ 55.],
#        [ 19.],
#        [ 56.],
#        [ 47.],
#        [ 56.],
#        [  2.],
#        [ 82.],
#        [ 57.],
#        [ 44.],
#        [ 26.],
#        [ 52.],
#        [ 41.],
#        [ 44.],
#        [  3.],
#        [ 31.],
#        [ 97.],
#        [ 21.],
#        [ 17.],
#        [  7.],
#        [ 61.],
#        [ 10.],
#        [ 52.],
#        [ 10.],
#        [ 65.],
#        [ 71.],
#        [  4.],
#        [ 24.],
#        [ 26.],
#        [ 51.],
#        [ 42.],
#        [ 62.],
#        [ 74.],
#        [ 77.],
#        [  3.],
#        [ 50.],
#        [ 24.],
#        [ 37.],
#        [ 58.],
#        [ 52.],
#        [ 27.],
#        [ 14.],
#        [100.],
#        [ 72.],
#        [  5.],
#        [ 71.],
#        [ 54.],
#        [ 84.],
#        [ 42.],
#        [ 54.],
#        [ 74.],
#        [ 54.],
#        [ 53.],
#        [ 78.],
#        [ 97.],
#        [ 49.],
#        [ 71.],
#        [ 48.],
#        [ 51.],
#        [ 89.],
#        [ 99.],
#        [ 93.],
#        [ 49.],
#        [ 18.],
#        [ 65.],
#        [ 83.],
#        [100.],
#        [ 41.],
#        [ 52.],
#        [ 29.],
#        [ 97.],
#        [  7.],
#        [ 51.],
#        [ 58.],
#        [ 50.],
#        [ 67.],
#        [ 89.],
#        [ 76.],
#        [ 35.],
#        [ 99.],
#        [ 31.],
#        [ 52.],
#        [ 11.],
#        [ 66.],
#        [ 50.],
#        [ 39.],
#        [ 60.],
#        [ 35.],
#        [ 53.],
#        [ 14.],
#        [ 49.],
#        [ 16.],
#        [ 76.],
#        [ 13.],
#        [ 51.],
#        [ 70.],
#        [ 98.],
#        [ 86.],
#        [100.],
#        [ 46.],
#        [ 51.],
#        [ 50.],
#        [ 91.],
#        [ 48.],
#        [ 81.],
#        [ 38.],
#        [ 40.],
#        [ 79.],
#        [ 96.],
#        [ 60.],
#        [ 70.],
#        [ 44.],
#        [ 11.],
#        [  6.],
#        [  5.],
#        [ 72.],
#        [ 55.],
#        [ 95.],
#        [ 41.],
#        [ 25.],
#        [  1.],
#        [ 55.],
#        [  4.],
#        [ 48.],
#        [ 55.],
#        [ 75.],
#        [ 68.],
#        [100.],
#        [ 25.],
#        [ 75.],
#        [ 34.],
#        [ 38.],
#        [ 92.],
#        [ 21.],
#        [ 88.],
#        [ 75.],
#        [ 76.],
#        [ 44.],
#        [ 10.],
#        [ 21.],
#        [ 16.],
#        [ 32.],
#        [ 13.],
#        [ 26.],
#        [ 70.],
#        [ 77.],
#        [ 77.],
#        [ 88.],
#        [ 35.],
#        [ 24.],
#        [ 17.],
#        [ 91.],
#        [ 32.],
#        [ 36.],
#        [ 89.],
#        [ 69.],
#        [ 30.],
#        [  6.],
#        [ 22.],
#        [ 67.],
#        [  9.],
#        [ 74.],
#        [ 50.],
#        [ 85.],
#        [  3.],
#        [  0.],
#        [ 59.],
#        [ 62.],
#        [ 17.],
#        [ 90.],
#        [ 23.],
#        [ 19.],
#        [ 93.],
#        [ 14.],
#        [ 58.],
#        [ 87.],
#        [ 37.],
#        [ 20.],
#        [ 35.],
#        [ 63.],
#        [ 56.],
#        [ 62.],
#        [ 98.],
#        [ 90.],
#        [ 51.],
#        [ 93.],
#        [ 22.],
#        [ 38.],
#        [ 13.],
#        [ 98.],
#        [ 99.],
#        [ 31.],
#        [ 94.],
#        [ 73.],
#        [ 37.],
#        [ 23.],
#        [ 11.],
#        [ 88.],
#        [ 47.],
#        [ 79.],
#        [ 91.],
#        [ 71.],
#        [ 10.],
#        [ 39.],
#        [ 92.],
#        [ 99.],
#        [ 28.],
#        [ 32.],
#        [ 32.],
#        [ 75.],
#        [ 99.],
#        [ 27.],
#        [ 64.],
#        [ 98.],
#        [ 38.],
#        [ 46.],
#        [ 13.],
#        [ 96.],
#        [  9.],
#        [ 34.],
#        [ 49.],
#        [  1.],
#        [ 50.],
#        [ 94.],
#        [ 27.],
#        [ 20.],
#        [ 12.],
#        [ 45.],
#        [ 91.],
#        [ 61.],
#        [ 10.],
#        [ 47.],
#        [ 33.],
#        [ 84.],
#        [ 24.],
#        [ 48.],
#        [ 48.],
#        [  9.],
#        [ 93.],
#        [ 99.],
#        [  8.],
#        [ 20.],
#        [ 38.],
#        [ 78.],
#        [ 81.],
#        [ 42.],
#        [ 95.],
#        [ 78.],
#        [ 44.],
#        [ 68.],
#        [ 87.],
#        [ 58.],
#        [ 52.],
#        [ 26.],
#        [ 75.],
#        [ 48.],
#        [ 71.],
#        [ 77.],
#        [ 34.],
#        [ 24.],
#        [ 70.],
#        [ 29.],
#        [ 76.],
#        [ 98.],
#        [ 28.],
#        [ 87.],
#        [  9.],
#        [ 87.],
#        [ 33.],
#        [ 64.],
#        [ 17.],
#        [ 49.],
#        [ 95.],
#        [ 75.],
#        [ 89.],
#        [ 81.],
#        [ 25.],
#        [ 47.],
#        [ 50.],
#        [  5.],
#        [ 68.],
#        [ 84.],
#        [  8.],
#        [ 41.],
#        [ 26.],
#        [ 89.],
#        [ 78.],
#        [ 34.],
#        [ 92.],
#        [ 27.],
#        [ 12.],
#        [  2.],
#        [ 22.],
#        [  0.],
#        [ 26.],
#        [ 50.],
#        [ 84.],
#        [ 70.],
#        [ 66.],
#        [ 42.],
#        [ 19.],
#        [ 94.],
#        [ 71.],
#        [ 19.],
#        [ 16.],
#        [ 49.],
#        [ 29.],
#        [ 29.],
#        [ 86.],
#        [ 50.],
#        [ 86.],
#        [ 30.],
#        [ 23.],
#        [ 20.],
#        [ 16.],
#        [ 57.],
#        [  8.],
#        [  8.],
#        [ 62.],
#        [ 55.],
#        [ 30.],
#        [ 86.],
#        [ 62.],
#        [ 51.],
#        [ 61.],
#        [ 86.],
#        [ 61.],
#        [ 21.],
#        [ 81.],
#        [ 97.],
#        [  5.],
#        [ 61.],
#        [ 47.],
#        [ 98.],
#        [ 30.],
#        [ 63.],
#        [  0.],
#        [100.],
#        [ 18.],
#        [ 30.],
#        [ 98.],
#        [ 16.],
#        [ 22.],
#        [ 55.],
#        [ 43.],
#        [ 75.],
#        [ 91.],
#        [ 46.],
#        [ 85.],
#        [ 55.],
#        [ 36.],
#        [ 49.],
#        [ 94.],
#        [ 43.],
#        [ 22.],
#        [ 37.],
#        [ 24.],
#        [ 95.],
#        [ 61.],
#        [ 75.],
#        [ 68.],
#        [ 58.],
#        [  5.],
#        [ 53.],
#        [ 80.],
#        [ 83.],
#        [ 25.],
#        [ 34.],
#        [ 26.],
#        [ 90.],
#        [ 60.],
#        [ 49.],
#        [ 19.],
#        [ 92.],
#        [ 29.],
#        [  8.],
#        [ 57.],
#        [ 29.],
#        [ 19.],
#        [ 81.],
#        [ 50.],
#        [ 15.],
#        [ 70.],
#        [ 39.],
#        [ 43.],
#        [ 21.],
#        [ 98.],
#        [ 86.],
#        [ 16.],
#        [ 25.],
#        [ 31.],
#        [ 93.],
#        [ 67.],
#        [ 49.],
#        [ 25.],
#        [ 88.],
#        [ 54.],
#        [ 21.],
#        [  8.],
#        [ 32.],
#        [ 35.],
#        [ 67.],
#        [ 90.],
#        [ 59.],
#        [ 15.],
#        [ 67.],
#        [ 42.],
#        [ 44.],
#        [ 77.],
#        [ 68.],
#        [ 36.],
#        [ 11.],
#        [ 10.],
#        [ 65.],
#        [ 98.],
#        [ 98.],
#        [ 49.],
#        [ 31.],
#        [ 56.],
#        [ 70.],
#        [ 91.],
#        [ 25.],
#        [ 54.],
#        [ 39.],
#        [ 91.],
#        [  3.],
#        [ 22.],
#        [  2.],
#        [  2.],
#        [ 65.],
#        [ 71.],
#        [ 42.],
#        [ 76.],
#        [ 43.],
#        [  8.],
#        [ 86.],
#        [ 87.],
#        [  3.],
#        [ 58.],
#        [ 62.],
#        [ 89.],
#        [ 95.],
#        [ 28.],
#        [  0.],
#        [  1.],
#        [ 49.],
#        [ 21.],
#        [ 46.],
#        [ 11.],
#        [ 89.],
#        [ 37.],
#        [ 29.],
#        [ 44.],
#        [ 96.],
#        [ 16.],
#        [ 74.],
#        [ 35.],
#        [ 42.],
#        [ 16.],
#        [ 56.],
#        [ 18.],
#        [100.],
#        [ 54.],
#        [ 92.],
#        [ 63.],
#        [ 81.],
#        [ 73.],
#        [ 48.],
#        [  1.],
#        [ 85.],
#        [ 14.],
#        [ 25.],
#        [ 45.],
#        [ 98.],
#        [ 97.],
#        [ 58.],
#        [ 93.],
#        [ 88.],
#        [ 89.],
#        [ 47.],
#        [  6.],
#        [ 34.],
#        [ 30.],
#        [ 16.],
#        [ 86.],
#        [ 40.],
#        [ 52.],
#        [ 15.],
#        [  4.],
#        [ 95.],
#        [ 99.],
#        [ 35.],
#        [ 58.],
#        [ 10.],
#        [ 16.],
#        [ 53.],
#        [ 58.],
#        [ 42.],
#        [ 24.],
#        [ 84.],
#        [ 64.],
#        [ 12.],
#        [ 61.],
#        [ 75.],
#        [ 15.],
#        [100.],
#        [ 43.],
#        [ 13.],
#        [ 48.],
#        [ 45.],
#        [ 52.],
#        [ 34.],
#        [ 30.],
#        [ 65.],
#        [100.],
#        [ 67.],
#        [ 99.],
#        [ 45.],
#        [ 87.],
#        [ 73.],
#        [  9.],
#        [ 81.],
#        [ 72.],
#        [ 81.],
#        [ 58.],
#        [ 93.],
#        [ 82.],
#        [ 66.],
#        [ 97.]])

# %%
reg1 = LinearRegression()
reg1.fit(x1,y1)
# Out:
# LinearRegression()

# %%
yhat1 = reg1.predict(x1)
reg_sc = reg1.score(x1,y1)

# %%
# Return the coefficient of determination of the prediction.
print("score:", reg_sc)
# Out:
# score: 0.9907015319025518

# %%
reg1.coef_[0]
# Out:
# 1.000656381856304

# %%
reg1.intercept_
# Out:
# -0.10726546430097272

# %%
test_df = pd.read_csv("data/linear_regression/test.csv")
test_df.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
x2 = test_df.x.values.reshape(-1, 1)
y2 = test_df.y.values

# %%
yhat2 = reg1.predict(x2)

# %%
yhat2
# Out:
# array([76.94327594, 20.90651855, 21.90717494, 19.90586217, 35.91636428,
#        14.90258026, 61.93343021, 94.95509081, 19.90586217,  4.89601644,
#         3.89536006, 18.90520579, 95.95574719, 61.93343021, 35.91636428,
#        14.90258026, 64.93539936, 13.90192388, 86.94983976, 68.93802488,
#        88.95115252, 50.92621001, 88.95115252, 26.91045685, 96.95640358,
#        57.93080468, 78.9445887 , 20.90651855, 92.95377805, 26.91045685,
#        98.95771634, 30.91308237, 32.91439514, 79.94524508, 27.91111323,
#        46.92358448, 52.92752277, 68.93802488, 27.91111323, 32.91439514,
#        90.95246528, 70.93933765, 49.92555363, 75.94261956,  3.89536006,
#        36.91702066, 69.93868127, 67.9373685 , 39.91898981, 34.9157079 ,
#        93.95443443, 87.95049614, 51.92686639, 30.91308237, 58.93146107,
#        -0.10726546, 38.91833343, 63.93474297, 68.93802488, 56.9301483 ,
#        12.9012675 , 71.93999403, 75.94261956, 60.93277383, 81.94655785,
#        17.90454941, 40.91964619, 49.92555363, 54.92883554, 12.9012675 ,
#        45.9229281 , 12.9012675 , 78.9445887 , 52.92752277, 14.90258026,
#        27.91111323, 80.94590147, 68.93802488, 51.92686639, 83.94787061,
#        67.9373685 , 26.91045685, 55.92949192, 47.92424086, 39.91898981,
#        38.91833343, 81.94655785, 99.95837272, 58.93146107, 42.92095896,
#        66.93671212, 37.91767705, 62.93408659, 90.95246528, 59.93211745,
#        13.90192388, 20.90651855, 86.94983976, 72.94065041, 31.91373876,
#         1.8940473 , 81.94655785, 18.90520579, 73.94130679, 41.92030257,
#        11.90061112,  0.89339092, 89.9518089 , 88.95115252, -0.10726546,
#        40.91964619, 15.90323665, 93.95443443, 96.95640358, 65.93605574,
#        23.9084877 , 16.90389303, 89.9518089 , 12.9012675 , -0.10726546,
#        63.93474297, 95.95574719, 97.95705996, 11.90061112, 40.91964619,
#        46.92358448, 77.94393232, 19.90586217, 88.95115252, 28.91176961,
#        63.93474297, 74.94196317, 11.90061112, 24.90914408, 27.91111323,
#        29.91242599, 64.93539936, 58.93146107, 63.93474297, 52.92752277,
#        70.93933765, 96.95640358, 72.94065041,  8.89864197, 11.90061112,
#        62.93408659, 98.95771634, 59.93211745, 34.9157079 ,  1.8940473 ,
#        59.93211745, 31.91373876, 93.95443443, 83.94787061, 62.93408659,
#        21.90717494, 80.94590147, 92.95377805, 32.91439514,  6.89732921,
#        41.92030257, 45.9229281 , 53.92817916, 15.90323665, 48.92489725,
#        42.92095896, 94.95509081, 65.93605574, 20.90651855, 34.9157079 ,
#        79.94524508, 36.91702066, 53.92817916, 55.92949192,  0.89339092,
#        31.91373876, 57.93080468, 31.91373876, 45.9229281 , 71.93999403,
#        16.90389303, 96.95640358, 92.95377805, 90.95246528, 36.91702066,
#         3.89536006, 53.92817916, 50.92621001, 26.91045685, 45.9229281 ,
#        91.95312167, 72.94065041, 76.94327594, 90.95246528, 60.93277383,
#        98.95771634,  3.89536006, 71.93999403, 18.90520579, 56.9301483 ,
#        77.94393232, 25.90980046, 73.94130679, 89.9518089 , 65.93605574,
#        12.9012675 , 39.91898981, 76.94327594, 66.93671212, 74.94196317,
#        22.90783132, 44.92227172, 58.93146107, 43.92161534, 22.90783132,
#        54.92883554, 54.92883554, 94.95509081, 11.90061112,  3.89536006,
#         6.89732921, 99.95837272, 47.92424086, 41.92030257, 95.95574719,
#        38.91833343, 99.95837272, 86.94983976, 13.90192388, 13.90192388,
#        36.91702066,  4.89601644, 87.95049614, 90.95246528, 64.93539936,
#        73.94130679, 55.92949192, 15.90323665,  4.89601644, 27.91111323,
#        91.95312167, 45.9229281 , 53.92817916, 38.91833343, 43.92161534,
#        30.91308237, 67.9373685 , 85.94918338, 89.9518089 , 37.91767705,
#        20.90651855, 94.95509081, 55.92949192, 59.93211745, 64.93539936,
#        77.94393232, 88.95115252,  5.89667283, 66.93671212, 35.91636428,
#        15.90323665, 99.95837272, 44.92227172, 72.94065041, 56.9301483 ,
#        19.90586217, 75.94261956, 33.91505152, 54.92883554, 71.93999403,
#        54.92883554,  7.89798559, 55.92949192, 71.93999403, 57.93080468,
#         5.89667283, 95.95574719, 22.90783132, 57.93080468, 22.90783132,
#        18.90520579, 24.90914408, 63.93474297, 20.90651855, 58.93146107,
#        18.90520579, 15.90323665, 41.92030257, 42.92095896, 60.93277383,
#        91.95312167, 10.89995474, 40.91964619,  0.89339092,  7.89798559,
#        70.93933765, 45.9229281 , 54.92883554, 61.93343021, 46.92358448])

# %%
plt.scatter(x=test_df.x, y=test_df.y)
plt.plot(x2, yhat2, c='r')

# %%
# ols performance
# R-square, t-test, p value
import statsmodels.api as sm
est = sm.OLS(y1, x1).fit()
print(est.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          2.955e+05
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):                        0.00
# Time:                        16:34:31   Log-Likelihood:                         -1712.9
# No. Observations:                 699   AIC:                                      3428.
# Df Residuals:                     698   BIC:                                      3432.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.9990      0.002    543.615      0.000       0.995       1.003
# ==============================================================================
# Omnibus:                        0.191   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.909   Jarque-Bera (JB):                0.246
# Skew:                           0.037   Prob(JB):                        0.884
# Kurtosis:                       2.945   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Exercise:
# 1. create a list of independent variable X and dependent variable Y.
# 2. try linear regression
# 3. predict y with some x values by your regression model
# 4. find the coefficient and intercept

# %%
# Q1
# X = np.array([[1,4],[3.3],[3.9],[4.2],[5.4]]).reshape(-1, 1)
X = np.array([1,4,3.3,3.9,4.2,5.4]).reshape(-1, 1)
# X1 = str(X).reshape(-1,1) # independent variables: 2 dimensional form 
Y = [2,7,7.5,8.3,10.5,11]

# Q2
l_reg = LinearRegression()
l_reg.fit(X,Y)

plt.scatter(X,Y)
plt.plot(X, l_reg.predict(X))
plt.show()

# Q3
y_hat = l_reg.predict([[1.5]])
print(y_hat)

# Q4
print("coefficient:",reg.coef_[0])

print("intercept:",reg.intercept_)
# Out:
# [3.24850374]
# coefficient: 2.094451371571072
# intercept: 0.1068266832917697
